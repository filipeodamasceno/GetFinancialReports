# %% [markdown]
# # 1 Manipulação de dados com Python/Pandas

# %% [markdown]
# ## 1.1 Importando Dataset

# %%
#Primeiro é necessário importar a biblioreca do Pandas

import pandas as pd

# %%
#É necessário colocar o separador do arquivo .csv para que os dados fiquem em colunas separadas

database = pd.read_csv(f'Datasets/GasPricesinBrazil_2004-2019.csv', sep=';')

# %% [markdown]
# ## 1.2. Exibindo as primeiras linhas do Dataset

# %%
database.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ## 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
database.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %% [markdown]
# 1.3.2 Dataframes

# %%
type(database)
# Out:
# pandas.core.frame.DataFrame

# %%
database.shape
# Out:
# (106823, 21)

# %%
print(f'O DataFrame possui {database.shape[0]} linhas/observaçãoes/registros e {database.shape[1]} colunas/atrubutos/variáveis')
# Out:
# O DataFrame possui 106823 linhas/observaçãoes/registros e 21 colunas/atrubutos/variáveis

# %% [markdown]
# Criando um DataFrame
#
# Podemos criar um DataFrame a partir de um dicionário, onde cada chave possui uma lista de elementos de igual tamanho.
# As chaves representam as colunas e cada um dos valores de sua lista representa o valor da linha correspondente para aquela coluna.

# %%
personagens_df = pd.DataFrame({
    'nome': ['Luke Skywalker','Yoda','Palpatine'],
    'idade': [16,1000,70],
    'peso': [70.5,15.2,60.1],
    'eh jedi': [True,True,False]
})

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %%
personagens_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      float64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 203.0+ bytes

# %%
personagens_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
list(personagens_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# ## Como renomear colunas:

# %%
personagens_df=personagens_df.rename(columns={
    'nome': 'Nome Completo',
    'idade': 'Idade',
    inplace = true
})

# %%
personagens_df
# Out:
#     Nome Completo  Idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %% [markdown]
# # 1.3.3 Series
#
# Array uni-dimensinonal com os dados e rótulos de um eixo

# %%
database.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
databaseFiltered = database[database['ESTADO']=='ALAGOAS'].copy()

PrecoMedRevenda = databaseFiltered['PREÇO MÉDIO REVENDA'].copy()
PrecoMaxRevenda = databaseFiltered['PREÇO MÁXIMO REVENDA'].copy()

DivPreco = PrecoMedRevenda/PrecoMaxRevenda

databaseFiltered.head()
# Out:
#      Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO   ESTADO           PRODUTO  \
# 4             4   2004-05-09  2004-05-15  NORDESTE  ALAGOAS  ETANOL HIDRATADO
# 31           31   2004-05-16  2004-05-22  NORDESTE  ALAGOAS  ETANOL HIDRATADO
# 58           58   2004-05-23  2004-05-29  NORDESTE  ALAGOAS  ETANOL HIDRATADO
# 85           85   2004-05-30  2004-06-05  NORDESTE  ALAGOAS  ETANOL HIDRATADO
# 112         112   2004-06-06  2004-06-12  NORDESTE  ALAGOAS  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 4                             103              R$/l                1.181
# 31                            106              R$/l                1.182
# 58                            103              R$/l                1.182
# 85                            105              R$/l                1.184
# 112                           103              R$/l                1.201
#
# ...

# %%
databaseFiltered.iloc[2500]
# Out:
# Unnamed: 0                                 62361
# DATA INICIAL                          2013-11-03
# DATA FINAL                            2013-11-09
# REGIÃO                                  NORDESTE
# ESTADO                                   ALAGOAS
# PRODUTO                          ÓLEO DIESEL S10
# NÚMERO DE POSTOS PESQUISADOS                  24
# UNIDADE DE MEDIDA                           R$/l
# PREÇO MÉDIO REVENDA                        2.444
# DESVIO PADRÃO REVENDA                      0.047
# PREÇO MÍNIMO REVENDA                        2.36
# PREÇO MÁXIMO REVENDA                       2.499
# MARGEM MÉDIA REVENDA                       0.275
# COEF DE VARIAÇÃO REVENDA                   0.019
# PREÇO MÉDIO DISTRIBUIÇÃO                   2.169
# DESVIO PADRÃO DISTRIBUIÇÃO                 0.035
# PREÇO MÍNIMO DISTRIBUIÇÃO                   2.13
# PREÇO MÁXIMO DISTRIBUIÇÃO                 2.2475
# COEF DE VARIAÇÃO DISTRIBUIÇÃO              0.016
# ...

# %%
DivPreco
# Out:
# 4         0.843571
# 31        0.844286
# 58        0.844286
# 85        0.763871
# 112       0.857857
#             ...
# 106701    0.902927
# 106728    0.911325
# 106755    0.891194
# 106782    0.890630
# 106808    0.934595
# Length: 4250, dtype: float64

# %% [markdown]
# ### Criando uma série

# %%
lista1 = pd.Series([5.5,7.2,8.7,9.0], index=['Prova1','Prova2','Prova3','Prova3'], name='Notas Damasceno')

lista1
# Out:
# Prova1    5.5
# Prova2    7.2
# Prova3    8.7
# Prova3    9.0
# Name: Notas Damasceno, dtype: float64

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %%
databaseFiltered.head()
# Out:
#      Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO   ESTADO           PRODUTO  \
# 4             4   2004-05-09  2004-05-15  NORDESTE  ALAGOAS  ETANOL HIDRATADO
# 31           31   2004-05-16  2004-05-22  NORDESTE  ALAGOAS  ETANOL HIDRATADO
# 58           58   2004-05-23  2004-05-29  NORDESTE  ALAGOAS  ETANOL HIDRATADO
# 85           85   2004-05-30  2004-06-05  NORDESTE  ALAGOAS  ETANOL HIDRATADO
# 112         112   2004-06-06  2004-06-12  NORDESTE  ALAGOAS  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 4                             103              R$/l                1.181
# 31                            106              R$/l                1.182
# 58                            103              R$/l                1.182
# 85                            105              R$/l                1.184
# 112                           103              R$/l                1.201
#
# ...

# %% [markdown]
# ### 1.3.4.1 Atribuindo constantes

# %%
databaseFiltered['REGIÃO'] = 'SUDESTE'

# %%
databaseFiltered.head()
# Out:
#      Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO ESTADO           PRODUTO  \
# 4             4   2004-05-09  2004-05-15  SUDESTE     SP  ETANOL HIDRATADO
# 31           31   2004-05-16  2004-05-22  SUDESTE     SP  ETANOL HIDRATADO
# 58           58   2004-05-23  2004-05-29  SUDESTE     SP  ETANOL HIDRATADO
# 85           85   2004-05-30  2004-06-05  SUDESTE     SP  ETANOL HIDRATADO
# 112         112   2004-06-06  2004-06-12  SUDESTE     SP  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 4                             103              R$/l                1.181
# 31                            106              R$/l                1.182
# 58                            103              R$/l                1.182
# 85                            105              R$/l                1.184
# 112                           103              R$/l                1.201
#
# ...

# %% [markdown]
# ### 1.3.4.2 Atribuindo listas ou series

# %%
lista = []

for i in range(5):
    lista.append(i)

# %%
lista
# Out:
# [0, 1, 2, 3, 4]

# %%
novos_produtos = [i for i in range(5)]

# %%
novos_produtos
# Out:
# [0, 1, 2, 3, 4]

# %%
nrows, ncols = databaseFiltered.shape
nrows, ncols
# Out:
# (4250, 21)

# %%
novos_produtos = [f'Produto {i}' for i in range(nrows)]

# %%
databaseFiltered['PRODUTO'] = novos_produtos

# %%
databaseFiltered.head()
# Out:
#      Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO ESTADO    PRODUTO  \
# 4             4   2004-05-09  2004-05-15  SUDESTE     SP  Produto 0
# 31           31   2004-05-16  2004-05-22  SUDESTE     SP  Produto 1
# 58           58   2004-05-23  2004-05-29  SUDESTE     SP  Produto 2
# 85           85   2004-05-30  2004-06-05  SUDESTE     SP  Produto 3
# 112         112   2004-06-06  2004-06-12  SUDESTE     SP  Produto 4
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 4                             103              R$/l                1.181
# 31                            106              R$/l                1.182
# 58                            103              R$/l                1.182
# 85                            105              R$/l                1.184
# 112                           103              R$/l                1.201
#
#      DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# ...

# %%
[a,b] = databaseFiltered.shape

# %%
[a,b]
# Out:
# [4250, 21]

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas

# %%
databaseFiltered.head()
# Out:
#      Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO ESTADO    PRODUTO  \
# 4             4   2004-05-09  2004-05-15  SUDESTE     SP  Produto 0
# 31           31   2004-05-16  2004-05-22  SUDESTE     SP  Produto 1
# 58           58   2004-05-23  2004-05-29  SUDESTE     SP  Produto 2
# 85           85   2004-05-30  2004-06-05  SUDESTE     SP  Produto 3
# 112         112   2004-06-06  2004-06-12  SUDESTE     SP  Produto 4
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 4                             103              R$/l                1.181
# 31                            106              R$/l                1.182
# 58                            103              R$/l                1.182
# 85                            105              R$/l                1.184
# 112                           103              R$/l                1.201
#
#      DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# ...

# %%
databaseFiltered['Nova1'] = [i for i in range(databaseFiltered.shape[0])]
databaseFiltered['Nova2'] = [i+1 for i in range(databaseFiltered.shape[0])]
databaseFiltered['Nova3'] = databaseFiltered['Nova1']/databaseFiltered['Nova2']

# %%
databaseFiltered
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO ESTADO       PRODUTO  \
# 4                4   2004-05-09  2004-05-15  SUDESTE     SP     Produto 0
# 31              31   2004-05-16  2004-05-22  SUDESTE     SP     Produto 1
# 58              58   2004-05-23  2004-05-29  SUDESTE     SP     Produto 2
# 85              85   2004-05-30  2004-06-05  SUDESTE     SP     Produto 3
# 112            112   2004-06-06  2004-06-12  SUDESTE     SP     Produto 4
# ...            ...          ...         ...      ...    ...           ...
# 106701      106701   2019-06-23  2019-06-29  SUDESTE     SP  Produto 4245
# 106728      106728   2019-06-23  2019-06-29  SUDESTE     SP  Produto 4246
# 106755      106755   2019-06-23  2019-06-29  SUDESTE     SP  Produto 4247
# 106782      106782   2019-06-23  2019-06-29  SUDESTE     SP  Produto 4248
# 106808      106808   2019-06-23  2019-06-29  SUDESTE     SP  Produto 4249
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# ## 1.4 Selecionando uma ou mais observações (Indexação)

# %% [markdown]
# ### ==> Index-based selection (seleção baseada em Índices)

# %%
database.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
database.iloc[0] #Seleciona uma linha inteira e retorna os valores de cada coluna
# Out:
# Unnamed: 0                                      0
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                           DISTRITO FEDERAL
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  127
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.288
# DESVIO PADRÃO REVENDA                       0.016
# PREÇO MÍNIMO REVENDA                         1.19
# PREÇO MÁXIMO REVENDA                         1.35
# MARGEM MÉDIA REVENDA                        0.463
# COEF DE VARIAÇÃO REVENDA                    0.012
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.825
# DESVIO PADRÃO DISTRIBUIÇÃO                   0.11
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.4201
# PREÇO MÁXIMO DISTRIBUIÇÃO                  0.9666
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.133
# ...

# %%
database.iloc[5:7] #Faz um corte do dataframe referente ao período que você colocou nos [a:b]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 5           5   2004-05-09  2004-05-15  NORDESTE  BAHIA  ETANOL HIDRATADO
# 6           6   2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 5                           408              R$/l                1.383
# 6                           278              R$/l                1.453
#
#    DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 5                  0.132  ...                  2.05                 0.426
# 6                  0.218  ...                  1.95                 0.353
#
#   COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                    0.095                     0.957
# 6                    0.150                       1.1
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5                      0.128                    0.5686
# ...

# %% [markdown]
# ### ==> Label-based selection (seleção baseadas em Rótulos)

# %%
ReportDRE = pd.read_csv(f'Datasets/Relatorio_cia_aberta_DRE_con_2011-2022_Filtrado.csv', sep=',')

# %%
ReportDRE.head()
# Out:
#              CNPJ_CIA    DT_REFER  VERSAO  \
# 0  00.001.180/0001-26  2011-03-31       1
# 1  00.001.180/0001-26  2011-03-31       1
# 2  00.001.180/0001-26  2011-03-31       1
# 3  00.001.180/0001-26  2011-03-31       1
# 4  00.001.180/0001-26  2011-03-31       1
#
#                               DENOM_CIA  CD_CVM  \
# 0  CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 1  CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 2  CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 3  CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 4  CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
#
#                                     GRUPO_DFP MOEDA ESCALA_MOEDA ORDEM_EXERC  \
# 0  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 1  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 2  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 3  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# ...

# %% [markdown]
# ## 1.5 Selecionando um ou mais atributos (colunas)

# %%
DF_Report_DRE_Filtered = ReportDRE[['DT_REFER','DENOM_CIA','DT_INI_EXERC','DT_FIM_EXERC','CD_CONTA','DS_CONTA','VL_CONTA']]

# %%
DF_Receita_DRE = DF_Report_DRE_Filtered[DF_Report_DRE['CD_CONTA'] == '3.01'].sort_values(by='DT_FIM_EXERC')

# %%
DF_Receita_DRE.head()
# Out:
#          DT_REFER                               DENOM_CIA DT_INI_EXERC  \
# 0      2011-03-31    CENTRAIS ELET BRAS S.A. - ELETROBRAS   2011-01-01
# 25600  2011-03-31                              TOTVS S.A.   2011-01-01
# 11152  2011-03-31           BROOKFIELD INCORPORAÇÕES S.A.   2011-01-01
# 25728  2011-03-31  JPSP INVESTIMENTOS E PARTICIPAÇÕES S/A   2011-01-01
# 11044  2011-03-31                            EMBRAER S.A.   2011-01-01
#
#       DT_FIM_EXERC CD_CONTA                                DS_CONTA   VL_CONTA
# 0       2011-03-31     3.01  Receita de Venda de Bens e/ou Serviços  8551982.0
# 25600   2011-03-31     3.01  Receita de Venda de Bens e/ou Serviços   305018.0
# 11152   2011-03-31     3.01  Receita de Venda de Bens e/ou Serviços   731137.0
# 25728   2011-03-31     3.01  Receita de Venda de Bens e/ou Serviços  1171093.0
# 11044   2011-03-31     3.01  Receita de Venda de Bens e/ou Serviços  1756604.0

# %%
DF_Receita_DRE.loc[0,'VL_CONTA']
# Out:
# 8551982.0

# %%
DF_Receita_DRE.shape
# Out:
# (16421, 7)

# %%
DF_Receita_DRE['DENOM_CIA']
# Out:
# 0                CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 25600                                      TOTVS S.A.
# 11152                   BROOKFIELD INCORPORAÇÕES S.A.
# 25728          JPSP INVESTIMENTOS E PARTICIPAÇÕES S/A
# 11044                                    EMBRAER S.A.
#                              ...
# 422518               WILSON SONS HOLDINGS BRASIL S.A.
# 422614    HOTEIS OTHON S.A. - EM RECUPERAÇÃO JUDICIAL
# 408844              OCEANPACT SERVIÇOS MARITIMOS S.A.
# 422833                    ULTRAPAR PARTICIPACOES S.A.
# 409309                             ANIMA HOLDING S.A.
# Name: DENOM_CIA, Length: 16421, dtype: object

# %%
DF_Receita_DRE.to_csv(f'Datasets/Relatorio_cia_aberta_Receitas_con_2011-2022_Filtrado.csv',index=False) #Salva arquivo em .csv

# %% [markdown]
# ## 1.6 Removendo um Atributo (Coluna) do Data Frame

# %%
ReportDRE = pd.read_csv(f'Datasets/Relatorio_cia_aberta_DRE_con_2011-2022_Filtrado.csv', sep=',')

# %%
ReportDRE.head()
# Out:
#              CNPJ_CIA    DT_REFER  VERSAO  \
# 0  00.001.180/0001-26  2011-03-31       1
# 1  00.001.180/0001-26  2011-03-31       1
# 2  00.001.180/0001-26  2011-03-31       1
# 3  00.001.180/0001-26  2011-03-31       1
# 4  00.001.180/0001-26  2011-03-31       1
#
#                               DENOM_CIA  CD_CVM  \
# 0  CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 1  CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 2  CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 3  CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 4  CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
#
#                                     GRUPO_DFP MOEDA ESCALA_MOEDA ORDEM_EXERC  \
# 0  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 1  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 2  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 3  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# ...

# %%
del ReportDRE['CNPJ_CIA']
del ReportDRE['VERSAO']
del ReportDRE['CD_CVM']
del ReportDRE['MOEDA']
del ReportDRE['ESCALA_MOEDA']
del ReportDRE['ORDEM_EXERC']
del ReportDRE['DT_FIM_EXERC']
del ReportDRE['DT_INI_EXERC']
del ReportDRE['ST_CONTA_FIXA']
del ReportDRE['GRUPO_DFP']

# %%
ReportDRE.head()
# Out:
#      DT_REFER                             DENOM_CIA CD_CONTA  \
# 0  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.01
# 1  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.02
# 2  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS  3.02.01
# 3  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS  3.02.02
# 4  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS  3.02.03
#
#                                  DS_CONTA   VL_CONTA
# 0  Receita de Venda de Bens e/ou Serviços  8551982.0
# 1   Custo dos Bens e/ou Serviços Vendidos -1127021.0
# 2                      Encargos Setoriais  -398353.0
# 3                                    ICMS  -252475.0
# 4                            PASEP/COFINS  -476193.0

# %% [markdown]
# ## 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um arquivo CSV, basta usarmos o método .to_csv.
# Por padrão, esse método salva os índices da tabela como uma coluna no CSV.
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).
# Desta forma, utilize o parâmetro: index=False.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro sep.

# %%
ReportDRE.to_csv(f'Datasets/Relatorio_cia_aberta_Receitas_con_2011-2022_Filtrado.csv',index=False) #Salva arquivo em .csv

# %% [markdown]
# ## 1.8 Seleção Condicional: Filtrando amostras

# %%
ReportDRE.head()
# Out:
#      DT_REFER                             DENOM_CIA  \
# 0  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 1  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 2  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 3  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 4  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
#
#                                     GRUPO_DFP CD_CONTA  \
# 0  DF Consolidado - Demonstração do Resultado     3.01
# 1  DF Consolidado - Demonstração do Resultado     3.02
# 2  DF Consolidado - Demonstração do Resultado  3.02.01
# 3  DF Consolidado - Demonstração do Resultado  3.02.02
# 4  DF Consolidado - Demonstração do Resultado  3.02.03
#
#                                  DS_CONTA   VL_CONTA
# 0  Receita de Venda de Bens e/ou Serviços  8551982.0
# 1   Custo dos Bens e/ou Serviços Vendidos -1127021.0
# 2                      Encargos Setoriais  -398353.0
# 3                                    ICMS  -252475.0
# ...

# %%
ReportDRE['DENOM_CIA'].unique()
# Out:
# array(['CENTRAIS ELET BRAS S.A. - ELETROBRAS',
#        'CIA ENERGETICA DE BRASILIA', 'VBC ENERGIA SA',
#        'NET SERVIÇOS DE COMUNICAÇÃO S.A.', 'FORPART S.A. - EM LIQUIDAÇÃO',
#        'KOSMOS COMÉRCIO DE VESTUÁRIO S/A - EM RECUPERAÇÃO JUDICIAL',
#        'STATKRAFT ENERGIAS RENOVAVEIS S.A.', 'LITEL PARTICIPACOES S.A.',
#        'AMERICANAS S.A.', 'ENERGISA S.A.',
#        'FERROVIA CENTRO-ATLANTICA S.A.',
#        'COMERCIAL QUINTELLA COM EXP SA EM LIQUIDAÇÃO', 'CIELO S.A.',
#        'NEOENERGIA S.A.', 'UNIVERSO ONLINE SA', 'GAFISA S.A.',
#        '521 PARTICIPACOES S.A. - EM LIQUIDAÇÃO EXTRAJUDICIAL',
#        'BELAPART SA', 'VALETRON SA', 'TAM S.A.', 'BRF S.A.',
#        'AES ELPA S.A.', 'CIA PARTICIPACOES ALIANCA DA BAHIA',
#        'SUL 116 PARTICIPACOES S.A.',
#        'EMPRESA NAC COM REDITO PART S.A.ENCORPAR',
#        'CIBRASEC - COMPANHIA BRASILEIRA DE SECURITIZACAO',
#        'TELEMAR PARTICIPAÇÕES SA', 'PORTO SEGURO S.A.',
# ...

# %%
pd.DataFrame(ReportDRE['DENOM_CIA'].unique()).head()
# Out:
#                                       0
# 0  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 1            CIA ENERGETICA DE BRASILIA
# 2                        VBC ENERGIA SA
# 3      NET SERVIÇOS DE COMUNICAÇÃO S.A.
# 4          FORPART S.A. - EM LIQUIDAÇÃO

# %%
selecao = ReportDRE['CD_CONTA'] =='3.01' #Faz uma comparação elemento a elemento da series, retornando uma series de booleans

# %%
selecao.shape
# Out:
# (582894,)

# %%
type(selecao)
# Out:
# pandas.core.series.Series

# %%
ReportDRE[selecao].head() #Filtra todos os valores Booleans = True
# Out:
#        DT_REFER                             DENOM_CIA  \
# 0    2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 42   2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 84   2011-09-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 137  2011-03-31            CIA ENERGETICA DE BRASILIA
# 180  2011-06-30            CIA ENERGETICA DE BRASILIA
#
#                                       GRUPO_DFP CD_CONTA  \
# 0    DF Consolidado - Demonstração do Resultado     3.01
# 42   DF Consolidado - Demonstração do Resultado     3.01
# 84   DF Consolidado - Demonstração do Resultado     3.01
# 137  DF Consolidado - Demonstração do Resultado     3.01
# 180  DF Consolidado - Demonstração do Resultado     3.01
#
#                                    DS_CONTA    VL_CONTA
# 0    Receita de Venda de Bens e/ou Serviços   8551982.0
# 42   Receita de Venda de Bens e/ou Serviços  13592265.0
# 84   Receita de Venda de Bens e/ou Serviços  20689462.0
# 137  Receita de Venda de Bens e/ou Serviços    320630.0
# ...

# %%
ReportDRE.loc[selecao] #Outra forma de fazer a filtragem
# Out:
#           DT_REFER                             DENOM_CIA  \
# 0       2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 42      2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 84      2011-09-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 137     2011-03-31            CIA ENERGETICA DE BRASILIA
# 180     2011-06-30            CIA ENERGETICA DE BRASILIA
# ...            ...                                   ...
# 582731  2021-12-31                CONSERVAS ODERICH S.A.
# 582761  2021-12-31                            DEXCO S.A.
# 582795  2022-03-31                      BANCO INTER S.A.
# 582833  2022-09-30                               TC S.A.
# 582863  2022-03-31                ATHENA SAÚDE BRASIL SA
#
#                                          GRUPO_DFP CD_CONTA  \
# 0       DF Consolidado - Demonstração do Resultado     3.01
# 42      DF Consolidado - Demonstração do Resultado     3.01
# 84      DF Consolidado - Demonstração do Resultado     3.01
# ...

# %%
ReportDRE.query('CD_CONTA == "3.01"').head()
# Out:
#        DT_REFER                             DENOM_CIA  \
# 0    2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 42   2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 84   2011-09-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 137  2011-03-31            CIA ENERGETICA DE BRASILIA
# 180  2011-06-30            CIA ENERGETICA DE BRASILIA
#
#                                       GRUPO_DFP CD_CONTA  \
# 0    DF Consolidado - Demonstração do Resultado     3.01
# 42   DF Consolidado - Demonstração do Resultado     3.01
# 84   DF Consolidado - Demonstração do Resultado     3.01
# 137  DF Consolidado - Demonstração do Resultado     3.01
# 180  DF Consolidado - Demonstração do Resultado     3.01
#
#                                    DS_CONTA    VL_CONTA
# 0    Receita de Venda de Bens e/ou Serviços   8551982.0
# 42   Receita de Venda de Bens e/ou Serviços  13592265.0
# 84   Receita de Venda de Bens e/ou Serviços  20689462.0
# 137  Receita de Venda de Bens e/ou Serviços    320630.0
# ...

# %%
DRE_301 = ReportDRE.query('CD_CONTA == "3.01"')

# %%
DRE_301.shape
# Out:
# (16421, 6)

# %%
ReportDRE.shape
# Out:
# (582894, 6)

# %%
DRE_301.head()
# Out:
#        DT_REFER                             DENOM_CIA  \
# 0    2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 42   2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 84   2011-09-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 137  2011-03-31            CIA ENERGETICA DE BRASILIA
# 180  2011-06-30            CIA ENERGETICA DE BRASILIA
#
#                                       GRUPO_DFP CD_CONTA  \
# 0    DF Consolidado - Demonstração do Resultado     3.01
# 42   DF Consolidado - Demonstração do Resultado     3.01
# 84   DF Consolidado - Demonstração do Resultado     3.01
# 137  DF Consolidado - Demonstração do Resultado     3.01
# 180  DF Consolidado - Demonstração do Resultado     3.01
#
#                                    DS_CONTA    VL_CONTA
# 0    Receita de Venda de Bens e/ou Serviços   8551982.0
# 42   Receita de Venda de Bens e/ou Serviços  13592265.0
# 84   Receita de Venda de Bens e/ou Serviços  20689462.0
# 137  Receita de Venda de Bens e/ou Serviços    320630.0
# ...

# %%
DRE_301.reset_index()
# Out:
#         index    DT_REFER                             DENOM_CIA  \
# 0           0  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 1          42  2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 2          84  2011-09-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 3         137  2011-03-31            CIA ENERGETICA DE BRASILIA
# 4         180  2011-06-30            CIA ENERGETICA DE BRASILIA
# ...       ...         ...                                   ...
# 16416  582731  2021-12-31                CONSERVAS ODERICH S.A.
# 16417  582761  2021-12-31                            DEXCO S.A.
# 16418  582795  2022-03-31                      BANCO INTER S.A.
# 16419  582833  2022-09-30                               TC S.A.
# 16420  582863  2022-03-31                ATHENA SAÚDE BRASIL SA
#
#                                         GRUPO_DFP CD_CONTA  \
# 0      DF Consolidado - Demonstração do Resultado     3.01
# 1      DF Consolidado - Demonstração do Resultado     3.01
# ...

# %%
DRE_301.reset_index(drop=True) #O DataFrame origical não foi alterado, deve ser utilizado o inplace = True
# Out:
#          DT_REFER                             DENOM_CIA  \
# 0      2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 1      2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 2      2011-09-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 3      2011-03-31            CIA ENERGETICA DE BRASILIA
# 4      2011-06-30            CIA ENERGETICA DE BRASILIA
# ...           ...                                   ...
# 16416  2021-12-31                CONSERVAS ODERICH S.A.
# 16417  2021-12-31                            DEXCO S.A.
# 16418  2022-03-31                      BANCO INTER S.A.
# 16419  2022-09-30                               TC S.A.
# 16420  2022-03-31                ATHENA SAÚDE BRASIL SA
#
#                                         GRUPO_DFP CD_CONTA  \
# 0      DF Consolidado - Demonstração do Resultado     3.01
# 1      DF Consolidado - Demonstração do Resultado     3.01
# 2      DF Consolidado - Demonstração do Resultado     3.01
# ...

# %%
DRE_301
# Out:
#           DT_REFER                             DENOM_CIA  \
# 0       2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 42      2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 84      2011-09-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 137     2011-03-31            CIA ENERGETICA DE BRASILIA
# 180     2011-06-30            CIA ENERGETICA DE BRASILIA
# ...            ...                                   ...
# 582731  2021-12-31                CONSERVAS ODERICH S.A.
# 582761  2021-12-31                            DEXCO S.A.
# 582795  2022-03-31                      BANCO INTER S.A.
# 582833  2022-09-30                               TC S.A.
# 582863  2022-03-31                ATHENA SAÚDE BRASIL SA
#
#                                          GRUPO_DFP CD_CONTA  \
# 0       DF Consolidado - Demonstração do Resultado     3.01
# 42      DF Consolidado - Demonstração do Resultado     3.01
# 84      DF Consolidado - Demonstração do Resultado     3.01
# ...

# %%
DRE_301.reset_index(drop=True, inplace=True)

# %%
DRE_301
# Out:
#          DT_REFER                             DENOM_CIA  \
# 0      2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 1      2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 2      2011-09-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 3      2011-03-31            CIA ENERGETICA DE BRASILIA
# 4      2011-06-30            CIA ENERGETICA DE BRASILIA
# ...           ...                                   ...
# 16416  2021-12-31                CONSERVAS ODERICH S.A.
# 16417  2021-12-31                            DEXCO S.A.
# 16418  2022-03-31                      BANCO INTER S.A.
# 16419  2022-09-30                               TC S.A.
# 16420  2022-03-31                ATHENA SAÚDE BRASIL SA
#
#                                         GRUPO_DFP CD_CONTA  \
# 0      DF Consolidado - Demonstração do Resultado     3.01
# 1      DF Consolidado - Demonstração do Resultado     3.01
# 2      DF Consolidado - Demonstração do Resultado     3.01
# ...

# %%
DRE_301 = ReportDRE.query('CD_CONTA == "3.01"')

# %%
DRE_301
# Out:
#           DT_REFER                             DENOM_CIA  \
# 0       2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 42      2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 84      2011-09-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 137     2011-03-31            CIA ENERGETICA DE BRASILIA
# 180     2011-06-30            CIA ENERGETICA DE BRASILIA
# ...            ...                                   ...
# 582731  2021-12-31                CONSERVAS ODERICH S.A.
# 582761  2021-12-31                            DEXCO S.A.
# 582795  2022-03-31                      BANCO INTER S.A.
# 582833  2022-09-30                               TC S.A.
# 582863  2022-03-31                ATHENA SAÚDE BRASIL SA
#
#                                          GRUPO_DFP CD_CONTA  \
# 0       DF Consolidado - Demonstração do Resultado     3.01
# 42      DF Consolidado - Demonstração do Resultado     3.01
# 84      DF Consolidado - Demonstração do Resultado     3.01
# ...

# %%
DRE_301 = ReportDRE.query('CD_CONTA == "3.01"').reset_index(drop=True)

# %%
DRE_301
# Out:
#          DT_REFER                             DENOM_CIA  \
# 0      2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 1      2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 2      2011-09-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 3      2011-03-31            CIA ENERGETICA DE BRASILIA
# 4      2011-06-30            CIA ENERGETICA DE BRASILIA
# ...           ...                                   ...
# 16416  2021-12-31                CONSERVAS ODERICH S.A.
# 16417  2021-12-31                            DEXCO S.A.
# 16418  2022-03-31                      BANCO INTER S.A.
# 16419  2022-09-30                               TC S.A.
# 16420  2022-03-31                ATHENA SAÚDE BRASIL SA
#
#                                         GRUPO_DFP CD_CONTA  \
# 0      DF Consolidado - Demonstração do Resultado     3.01
# 1      DF Consolidado - Demonstração do Resultado     3.01
# 2      DF Consolidado - Demonstração do Resultado     3.01
# ...

# %% [markdown]
# ### Filtrando com valores numéricos

# %%
ReportDRE.head()
# Out:
#      DT_REFER                             DENOM_CIA  \
# 0  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 1  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 2  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 3  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
# 4  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS
#
#                                     GRUPO_DFP CD_CONTA  \
# 0  DF Consolidado - Demonstração do Resultado     3.01
# 1  DF Consolidado - Demonstração do Resultado     3.02
# 2  DF Consolidado - Demonstração do Resultado  3.02.01
# 3  DF Consolidado - Demonstração do Resultado  3.02.02
# 4  DF Consolidado - Demonstração do Resultado  3.02.03
#
#                                  DS_CONTA   VL_CONTA
# 0  Receita de Venda de Bens e/ou Serviços  8551982.0
# 1   Custo dos Bens e/ou Serviços Vendidos -1127021.0
# 2                      Encargos Setoriais  -398353.0
# 3                                    ICMS  -252475.0
# ...

# %%
ReportDRE['DENOM_CIA'].unique()
# Out:
# array(['CENTRAIS ELET BRAS S.A. - ELETROBRAS',
#        'CIA ENERGETICA DE BRASILIA', 'VBC ENERGIA SA',
#        'NET SERVIÇOS DE COMUNICAÇÃO S.A.', 'FORPART S.A. - EM LIQUIDAÇÃO',
#        'KOSMOS COMÉRCIO DE VESTUÁRIO S/A - EM RECUPERAÇÃO JUDICIAL',
#        'STATKRAFT ENERGIAS RENOVAVEIS S.A.', 'LITEL PARTICIPACOES S.A.',
#        'AMERICANAS S.A.', 'ENERGISA S.A.',
#        'FERROVIA CENTRO-ATLANTICA S.A.',
#        'COMERCIAL QUINTELLA COM EXP SA EM LIQUIDAÇÃO', 'CIELO S.A.',
#        'NEOENERGIA S.A.', 'UNIVERSO ONLINE SA', 'GAFISA S.A.',
#        '521 PARTICIPACOES S.A. - EM LIQUIDAÇÃO EXTRAJUDICIAL',
#        'BELAPART SA', 'VALETRON SA', 'TAM S.A.', 'BRF S.A.',
#        'AES ELPA S.A.', 'CIA PARTICIPACOES ALIANCA DA BAHIA',
#        'SUL 116 PARTICIPACOES S.A.',
#        'EMPRESA NAC COM REDITO PART S.A.ENCORPAR',
#        'CIBRASEC - COMPANHIA BRASILEIRA DE SECURITIZACAO',
#        'TELEMAR PARTICIPAÇÕES SA', 'PORTO SEGURO S.A.',
# ...

# %% [markdown]
# ### Filtrar todas as linhas de receita da 'WEG S.A.'
#
# Utilizando multiplos filtros

# %%
conta = ReportDRE['CD_CONTA'] =='3.01'
empresa = ReportDRE['DENOM_CIA'] =='WEG S.A.'
periodo = ReportDRE['DT_REFER'].str.contains('-12-31')
valores = ReportDRE['VL_CONTA'] > 10000000
#periodo = ReportDRE['DT_REFER'] =='-01-01'
filtro = (conta & empresa & periodo & valores) #Utilizar | para OR

# %%
filtro
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 582889    False
# 582890    False
# 582891    False
# 582892    False
# 582893    False
# Length: 582894, dtype: bool

# %%
DRE_301_WEG = ReportDRE[filtro].reset_index(drop=True)

# %%
DRE_301_WEG
# Out:
#      DT_REFER DENOM_CIA                                   GRUPO_DFP CD_CONTA  \
# 0  2018-12-31  WEG S.A.  DF Consolidado - Demonstração do Resultado     3.01
# 1  2019-12-31  WEG S.A.  DF Consolidado - Demonstração do Resultado     3.01
# 2  2020-12-31  WEG S.A.  DF Consolidado - Demonstração do Resultado     3.01
# 3  2021-12-31  WEG S.A.  DF Consolidado - Demonstração do Resultado     3.01
#
#                                  DS_CONTA    VL_CONTA
# 0  Receita de Venda de Bens e/ou Serviços  11970090.0
# 1  Receita de Venda de Bens e/ou Serviços  13347434.0
# 2  Receita de Venda de Bens e/ou Serviços  17469557.0
# 3  Receita de Venda de Bens e/ou Serviços  23563338.0

# %%
# %matplotlib inLine

# %%
DRE_301_WEG_plot = DRE_301_WEG[['DT_REFER','VL_CONTA']]

# %%
DRE_301_WEG.plot.bar()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Criando vários um DataFrame para cada conta contábil

# %%
ReportDRE.head()
# Out:
#      DT_REFER                             DENOM_CIA CD_CONTA  \
# 0  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.01
# 1  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.02
# 2  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS  3.02.01
# 3  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS  3.02.02
# 4  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS  3.02.03
#
#                                  DS_CONTA   VL_CONTA
# 0  Receita de Venda de Bens e/ou Serviços  8551982.0
# 1   Custo dos Bens e/ou Serviços Vendidos -1127021.0
# 2                      Encargos Setoriais  -398353.0
# 3                                    ICMS  -252475.0
# 4                            PASEP/COFINS  -476193.0

# %%
ReportDRE['DS_CONTA'].unique()
# Out:
# array(['Receita de Venda de Bens e/ou Serviços',
#        'Custo dos Bens e/ou Serviços Vendidos', 'Encargos Setoriais', ...,
#        'Amortização Ativo Financeiro', 'Receita líquida com serviços',
#        'Participação dos empregados'], dtype=object)

# %%
listaConta = ['3.01','3.02','3.03','3.04','3.05','3.06','3,07','3.08','3.09','3.10','3.11']
selecao = ReportDRE['CD_CONTA'].isin(listaConta)

# %%
ReportDRE[selecao].head(20)
# Out:
#       DT_REFER                             DENOM_CIA CD_CONTA  \
# 0   2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.01
# 1   2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.02
# 5   2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.03
# 6   2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.04
# 24  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.05
# 25  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.06
# 29  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.08
# 32  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.09
# 33  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.10
# 36  2011-03-31  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.11
# 42  2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.01
# 43  2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.02
# 44  2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.03
# 45  2011-06-30  CENTRAIS ELET BRAS S.A. - ELETROBRAS     3.04
# ...
